# %%
# %cd ..
# Out:
# /Users/crupley/gal/hoodie

# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cPickle as pickle

# %%
df = pickle.load(open('featuresdf.pkl', 'rb'))
df.shape
# Out:
# (7334, 11)

# %%
df.plot(kind='scatter', x='lon', y='lat', linewidths = 0, figsize = (10, 10))
plt.axis('equal')
plt.margins(0)
ax = plt.gca()
ax.get_xaxis().get_major_formatter().set_useOffset(False)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib inline

# %%
# %matplotlib notebook

# %%
df[(df.lon < -122.375) | (df.lat < 37.805)].plot(kind='scatter', x='lon', y='lat', linewidths = 0, figsize = (10, 10))
plt.hold(True)
plt.plot(list(df.ix[[5662, 6742]].lon.values), list(df.ix[[5662, 6742]].lat.values), 'r.')
plt.axis('equal')
plt.margins(0)
ax = plt.gca()
ax.get_xaxis().get_major_formatter().set_useOffset(False)
ax.get_yaxis().get_major_formatter().set_useOffset(False)

# %%
print df.shape
print df.drop([5662, 6472], axis=0).shape
# Out:
# (7334, 11)
# (7332, 11)
