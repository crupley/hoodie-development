# %%
cd ..
# Out:
# /Users/crupley/gal/hoodie

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import psycopg2

# %%
from code.makedbs import *
from code.featurize import *

# %% [markdown]
# # assessment

# %%
df = pd.read_csv('../data/assessment/Secured_Property_Assessment_Roll_FY13_Q4.csv')
# Out:
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2871: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   Situs_Address Situs_Zip      APN     RE RE_Improvements Fixtures_Value  \
# 0           NaN     94102  0001001  $0.00           $0.00            NaN
# 1           NaN     94102  0002001  $0.00           $0.00            NaN
# 2           NaN     94102  0004002  $0.00           $0.00            NaN
# 3           NaN     94102  0005001  $0.00           $0.00            NaN
# 4           NaN     94102  0006001  $0.00           $0.00            NaN
#
#   PP_Value          District Taxable_Value  \
# 0    $0.00  General Property         $0.00
# 1    $0.00  General Property         $0.00
# 2    $0.00  General Property         $0.00
# 3    $0.00  General Property         $0.00
# 4    $0.00  General Property         $0.00
#
#                                     geom
# 0  (37.8086657345267, -122.421558691582)
# 1  (37.8087296429956, -122.420498649163)
# 2  (37.8085082551122, -122.415083280065)
# 3  (37.8084147785698, -122.416681695182)
# 4  (37.8083224324003, -122.418348971767)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204541 entries, 0 to 204540
# Data columns (total 10 columns):
# Situs_Address      202778 non-null object
# Situs_Zip          204478 non-null object
# APN                204541 non-null object
# RE                 204541 non-null object
# RE_Improvements    204541 non-null object
# Fixtures_Value     1146 non-null object
# PP_Value           204541 non-null object
# District           203974 non-null object
# Taxable_Value      204541 non-null object
# geom               204541 non-null object
# dtypes: object(10)
# memory usage: 17.2+ MB

# %%
list(df.columns)
# Out:
# ['Situs_Address',
#  'Situs_Zip',
#  'APN',
#  'RE',
#  'RE_Improvements',
#  'Fixtures_Value',
#  'PP_Value',
#  'District',
#  'Taxable_Value',
#  'geom']

# %%
df.RE = df.RE.apply(lambda x: x.strip('$'))

# %%
df.RE = df.RE.astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204541 entries, 0 to 204540
# Data columns (total 10 columns):
# Situs_Address      202778 non-null object
# Situs_Zip          204478 non-null object
# APN                204541 non-null object
# RE                 204541 non-null float64
# RE_Improvements    204541 non-null object
# Fixtures_Value     1146 non-null object
# PP_Value           204541 non-null object
# District           203974 non-null object
# Taxable_Value      204541 non-null object
# geom               204541 non-null object
# dtypes: float64(1), object(9)
# memory usage: 17.2+ MB

# %%
# %run ../code/makedbs.py

# %%
make_assessment()
# Out:
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2981: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
print df.info()
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-7d65c69160e1> in <module>()
#       1 get_ipython().magic(u'run ../code/makedbs.py')
#       2 df = make_assessment()
# ----> 3 print df.info()
#       4 df.head()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
list(df.columns)
# Out:
# ['Situs_Address',
#  'Situs_Zip',
#  'APN',
#  'RE',
#  'RE_Improvements',
#  'PP_Value',
#  'District',
#  'Taxable_Value',
#  'lat',
#  'lon']

# %% [markdown]
# # business

# %%
df = pd.read_csv('../data/business/Registered_Business_Locations_-_San_Francisco.csv')
df.head()
# Out:
#       Location_ID  Business_Account_Number     Ownership_Name  \
# 0  0000024-02-999                       24   EASTMAN KODAK CO
# 1  0000028-02-001                       28    FERRANDO LOUISE
# 2  0000052-01-001                       52   IDEAL NOVAK CORP
# 3  0000071-01-001                       71  TOURNAHU GEORGE L
# 4  0000071-02-001                       71  TOURNAHU GEORGE L
#
#                     DBA Name     Street_Address           City State  \
# 0           EASTMAN KODAK CO       343 STATE ST      ROCHESTER    NY
# 1           3101 LAGUNA APTS     3101 LAGUNA ST  San Francisco    CA
# 2           IDEAL NOVAK CORP      8 MENDOSA AVE  San Francisco    CA
# 3              TOURNAHU ARMS  1842 JEFFERSON ST  San Francisco    CA
# 4  3301 BRODERICK APARTMENTS  3301 BRODERICK ST  San Francisco    CA
#
#    Zip_Code Business_Start_Date Business_End_Date Location Start Date  \
# 0     14650          01/01/2003               NaN          01/01/2003
# 1     94123          09/30/1993               NaN          09/30/1993
# 2     94116          10/01/1968               NaN          10/01/1968
# 3     94123          10/01/1968               NaN          10/01/1968
# 4     94123          10/01/1968               NaN          05/01/1988
#
#   Location_End_Date          Mail_Address          Mail_City_State_Zip  \
# 0               NaN      343 STATE STREET      ROCHESTER NY 14650-0904
# 1               NaN    2799 CALIFORNIA ST  SAN FRANCISCO CA 94115-2513
# 2               NaN         8 MENDOSA AVE  SAN FRANCISCO CA 94116-1942
# 3               NaN  4444 GEARY BLVD. 100      SAN FRANCISCO CA 94118-
# 4               NaN  4444 GEARY BLVD. 100      SAN FRANCISCO CA 94118-
#
#   Class Code PBC Code                                  Business_Location
# 0         08     5995  343 STATE ST\nROCHESTER, NY 14650\n(43.161198,...
# 1         07     7520  3101 LAGUNA ST\nSan Francisco, CA 94123\n(37.7...
# 2         03     6511  8 MENDOSA AVE\nSan Francisco, CA 94116\n(37.74...
# 3         07     0211  1842 JEFFERSON ST\nSan Francisco, CA 94123\n(3...
# 4         07     0211  3301 BRODERICK ST\nSan Francisco, CA 94123\n(3...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156111 entries, 0 to 156110
# Data columns (total 17 columns):
# Location_ID                156111 non-null object
# Business_Account_Number    156111 non-null int64
# Ownership_Name             156111 non-null object
# DBA Name                   156109 non-null object
# Street_Address             156109 non-null object
# City                       155839 non-null object
# State                      155463 non-null object
# Zip_Code                   156067 non-null float64
# Business_Start_Date        156111 non-null object
# Business_End_Date          17770 non-null object
# Location Start Date        156111 non-null object
# Location_End_Date          26668 non-null object
# Mail_Address               156110 non-null object
# Mail_City_State_Zip        156110 non-null object
# Class Code                 155969 non-null object
# PBC Code                   155739 non-null object
# Business_Location          155731 non-null object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 21.4+ MB

# %%
for i in df.columns: print i
# Out:
# Location_ID
# Business_Account_Number
# Ownership_Name
# DBA Name
# Street_Address
# City
# State
# Zip_Code
# Business_Start_Date
# Business_End_Date
# Location Start Date
# Location_End_Date
# Mail_Address
# Mail_City_State_Zip
# Class Code
# PBC Code
# Business_Location

# %%
# %run ../code/makedbs.py
make_business()

# %%
pbc = pd.read_csv('../data/business/Principal_Business_Code__PBC__List.csv')
print pbc.shape
pbc.head()
# Out:
# (672, 4)
#   Ownership_Type  Business_Major_Class  Business_Minor_Class  \
# 0              S                     0                     0
# 1              P                     0                     0
# 2              C                     0                     0
# 3              S                     1                  2634
# 4              S                     1                  2675
#
#                        Description
# 0     FIXED PLACE OF BUSINESS BP99
# 1     FIXED PLACE OF BUSINESS BP99
# 2     FIXED PLACE OF BUSINESS BP99
# 3      AGENT/BROKER - DURABLE BP50
# 4   AGENT/BROKER - NONDURABLE BP51

# %%
pbc.groupby('Business_Major_Class').count()
# Out:
#                       Ownership_Type  Business_Minor_Class  Description
# Business_Major_Class
# 0                                  3                     3            3
# 1                                 30                    30           30
# 2                                 37                    37           37
# 3                                 20                    20           20
# 4                                 10                    10           10
# 5                                  8                     8            8
# 6                                 11                    11           11
# 7                                243                   243          243
# 8                                143                   143          143
# 9                                  7                     7            7
# 10                                15                    15           15
# 11                                 9                     9            9
# 12                                 3                     3            3
# 13                               123                   123          123
# 15                                 4                     4            4
# 16                                 3                     3            3
# 18                                 3                     3            3

# %%
pbc[pbc.Business_Major_Class == 8]
# Out:
#     Ownership_Type  Business_Major_Class  Business_Minor_Class  \
# 362              S                     8                   612
# 363              S                     8                  3012
# 364              S                     8                  3038
# 365              S                     8                  3053
# 366              S                     8                  3079
# 367              S                     8                  3095
# 368              S                     8                  3210
# 369              S                     8                  3236
# 370              S                     8                  3251
# 371              S                     8                  3277
# 372              S                     8                  3319
# 373              S                     8                  3335
# 374              S                     8                  3517
# 375              S                     8                  3533
# 376              S                     8                  3558
# 377              S                     8                  3715
# 378              S                     8                  3731
# 379              S                     8                  3756
# 380              S                     8                  3772
# 381              S                     8                  3913
# 382              S                     8                  3939
# 383              S                     8                  3954
# 384              S                     8                  3970
# 385              S                     8                  3988
# 386              S                     8                  3996
# 387              S                     8                  4119
# 388              S                     8                  4317
# 389              S                     8                  4333
# 390              S                     8                  4416
# 391              S                     8                  4432
# ..             ...                   ...                   ...
# 475              C                     8                  4600
# 476              C                     8                  4700
# 477              C                     8                  4830
# 478              C                     8                  5220
# 479              C                     8                  5251
# 480              C                     8                  5265
# 481              C                     8                  5300
# 482              C                     8                  5410
# 483              C                     8                  5490
# 484              C                     8                  5495
# 485              C                     8                  5515
# 486              C                     8                  5541
# 487              C                     8                  5598
# 488              C                     8                  5600
# 489              C                     8                  5700
# 490              C                     8                  5800
# 491              C                     8                  5912
# 492              C                     8                  5921
# 493              C                     8                  5995
# 494              C                     8                  6030
# 495              C                     8                  6060
# 496              C                     8                  6090
# 497              C                     8                  6120
# 498              C                     8                  6140
# 499              C                     8                  6299
# 500              C                     8                  6355
# 501              C                     8                  6356
# 502              C                     8                  6359
# 503              C                     8                  7900
# 504              C                     8                  8888
#
#                                            Description
# 362                   BAKERIES SELLING AT RETAIL BP205
# 363   SELLING DOOR-TO-DOOR,BY PHONE/PARTY PLAN,MOBI...
# 364                       CATALOG OR MAIL ORDER BP5961
# 365                     VENDING MACHINE SELLING BP5962
# 366   EATING PLACES (MEALS OR SNACKS) RESTAURANTS B...
# 367        DRINKING PLACES(ALCOHOLIC BEVERAGES) BP5813
# 368                 GROCERY STORES(GENERAL LINE) BP541
# 369           FOOD STORES(MEAT,PRODUCE,CANDY,ETC) BP54
# 370                                LIQUOR STORES BP592
# 371                                  DRUG STORES BP591
# 372                              NEW CAR DEALERS BP551
# 373                             USED CAR DEALERS BP552
# 374    AUTO DEALERS(MOTORCYCLES,RECREATION VECH.) BP55
# 375                  TIRES,ACCESSORIES,AND PARTS BP553
# 376                    GASOLINE SERVICE STATIONS BP554
# 377                               VARIETY STORES BP533
# 378                   GENERAL MERCHANDISE STORES BP539
# 379                                  SHOE STORES BP566
# 380              MEN'S AND BOYS' CLOTHING STORES BP561
# 381   WOMEN'S READY-TO-WEAR STORES BP562S 08 3921 W...
# 382                       FAMILY CLOTHING STORES BP565
# 383                 APPAREL AND ACCESSORY STORES BP569
# 384                             FURNITURE STORES BP571
# 385                COMPUTER AND SOFTWARE STORES BP5734
# 386                    TV,AUDIO,AND ELECTRONICS BP5731
# 387                   HOUSEHOLD APPLIANCE STORES BP572
# 388   HOME FURNISHINGS STORES(CHINA,FLOOR COVER.) B...
# 389                      MUSIC AND RECORD STORES BP573
# 390                   BUILDING MATERIALS DEALERS BP521
# 391             PAINT,GLASS,AND WALLPAPER STORES BP523
# ..                                                 ...
# 475                 PIPE LINES,EXCEPT NATURAL GAS BP46
# 476         MISCELLANEOUS TRANSPORTATION SERVICES BP47
# 477            RADIO AND TELEVISION BROADCASTING BP483
# 478                    BUILDING MATERIALS DEALERS BP52
# 479                              HARDWARE STORES BP525
# 480       GARDEN SUPPLIES AND MOBILE HOME DEALERS BP52
# 481                    GENERAL MERCHANDISE STORES BP53
# 482                               GROCERY STORES BP541
# 483                             OTHER FOOD STORES BP54
# 484                          OTHER RETAIL STORES BP599
# 485                         MOTOR VEHICLE DEALERS BP55
# 486                    GASOLINE SERVICE STATIONS BP554
# 487                            AUTOMOTIVE DEALERS BP55
# 488                  APPAREL AND ACCESSORY STORES BP56
# 489         FURNITURE AND HOME FURNISHINGS STORES BP57
# 490      EATING AND DRINKING PLACES (RESTAURANTS) BP58
# 491           DRUG STORES AND PROPRIETARY STORES BP591
# 492                                LIQUOR STORES BP592
# 493                                 RETAIL STORES BP59
# 494                           MUTUAL SAVINGS BANK BP60
# 495                      BANK HOLDING COMPANIES BP6712
# 496           BANKS, EXCEPT MUTUAL SAVINGS BANKS BP602
# 497                SAVINGS AND LOAN ASSOCIATIONS BP603
# 498                 PERSONAL CREDIT INSTITUTIONS BP614
# 499     COMMODITY CONTRACT BROKERS AND DEALER SEC BP62
# 500                               LIFE INSURANCE BP631
# 501       MUTUAL INSURANCE EXCEPT LIFE OR MARINE BP639
# 502                    OTHER INSURANCE COMPANIES BP639
# 503   AMUSEMENT RECREATION SERVICE EXCEPT MOTION PI...
# 504                            UNABLE TO CLASSIFY BP99
#
# [143 rows x 4 columns]

# %%
df.groupby('Class Code').count()
# Out:
#             Location_ID  Business_Account_Number  Ownership_Name  DBA Name  \
# Class Code
# 00                   23                       23              23        23
# 01                 3087                     3087            3087      3087
# 02                12234                    12234           12234     12234
# 03                 9730                     9730            9730      9730
# 04                  689                      689             689       689
# 05                   57                       57              57        57
# 06                  407                      407             407       407
# 07                65906                    65906           65906     65905
# 08                20322                    20322           20322     20322
# 09                  164                      164             164       164
# 10                  663                      663             663       663
# 11                 5292                     5292            5292      5292
# 12                  215                      215             215       215
# 13                 4497                     4497            4497      4497
# 15                 1449                     1449            1449      1449
# 16                    5                        5               5         5
# n.a.              31229                    31229           31229     31228
#
#             Street_Address   City  State  Zip_Code  Business_Start_Date  \
# Class Code
# 00                      23     23     23        23                   23
# 01                    3087   3086   3083      3087                 3087
# 02                   12234  12183  12049     12232                12234
# 03                    9730   9730   9728      9730                 9730
# 04                     689    689    687       689                  689
# 05                      57     56     56        57                   57
# 06                     407    406    397       407                  407
# 07                   65906  65820  65760     65897                65906
# 08                   20322  20280  20229     20321                20322
# 09                     164    164    163       164                  164
# 10                     663    619    618       663                  663
# 11                    5292   5281   5281      5291                 5292
# 12                     215    214    212       215                  215
# 13                    4497   4473   4386      4497                 4497
# 15                    1449   1447   1442      1449                 1449
# 16                       5      5      5         5                    5
# n.a.                 31227  31222  31203     31198                31229
#
#             Business_End_Date  Location Start Date  Location_End_Date  \
# Class Code
# 00                          0                   23                  3
# 01                        248                 3087                435
# 02                       1418                12234               1823
# 03                        651                 9730               1331
# 04                         64                  689                 90
# 05                          4                   57                 10
# 06                         29                  407                 49
# 07                       6938                65906              10650
# 08                       2227                20322               3084
# 09                         19                  164                 21
# 10                         37                  663                 56
# 11                        564                 5292                652
# 12                         18                  215                 25
# 13                        475                 4497                633
# 15                        124                 1449                228
# 16                          0                    5                  0
# n.a.                     4953                31229               7563
#
#             Mail_Address  Mail_City_State_Zip  PBC Code  Business_Location
# Class Code
# 00                    23                   23        23                 23
# 01                  3087                 3087      3085               3079
# 02                 12234                12234     12230              12190
# 03                  9730                 9730      9618               9727
# 04                   689                  689       687                689
# 05                    57                   57        57                 56
# 06                   407                  407       404                405
# 07                 65906                65906     65823              65825
# 08                 20322                20322     20305              20296
# 09                   164                  164       164                164
# 10                   663                  663       663                658
# 11                  5292                 5292      5291               5163
# 12                   215                  215       215                213
# 13                  4497                 4497      4492               4467
# 15                  1449                 1449      1448               1449
# 16                     5                    5         5                  5
# n.a.               31228                31228     31229              31180

# %%
major_names = {'00': 'fixed place of business',
               '01': 'agent, broker',
               '02': 'construction',
               '03': 'hotel',
               '04': 'laundry',
               '05': 'credit',
               '06': 'equipment rental',
               '07': 'mining, entertainment, medical',
               '08': 'clothing, furniture, auto, insurance',
               '09': 'warehouse',
               '10': 'utility',
               '11': 'taxi',
               '12': 'trucking',
               '13': 'industrial supply',
               '15': 'arcitectural',
               '16': 'garage',
               '18': 'firearms',
               'n.a.': 'n.a.'}

# %%
# Out:
#       Location_ID  Business_Account_Number     Ownership_Name  \
# 0  0000024-02-999                       24   EASTMAN KODAK CO
# 1  0000028-02-001                       28    FERRANDO LOUISE
# 2  0000052-01-001                       52   IDEAL NOVAK CORP
# 3  0000071-01-001                       71  TOURNAHU GEORGE L
# 4  0000071-02-001                       71  TOURNAHU GEORGE L
#
#                     DBA Name     Street_Address           City State  \
# 0           EASTMAN KODAK CO       343 STATE ST      ROCHESTER    NY
# 1           3101 LAGUNA APTS     3101 LAGUNA ST  San Francisco    CA
# 2           IDEAL NOVAK CORP      8 MENDOSA AVE  San Francisco    CA
# 3              TOURNAHU ARMS  1842 JEFFERSON ST  San Francisco    CA
# 4  3301 BRODERICK APARTMENTS  3301 BRODERICK ST  San Francisco    CA
#
#    Zip_Code Business_Start_Date Business_End_Date Location Start Date  \
# 0     14650          01/01/2003               NaN          01/01/2003
# 1     94123          09/30/1993               NaN          09/30/1993
# 2     94116          10/01/1968               NaN          10/01/1968
# 3     94123          10/01/1968               NaN          10/01/1968
# 4     94123          10/01/1968               NaN          05/01/1988
#
#   Location_End_Date          Mail_Address          Mail_City_State_Zip  \
# 0               NaN      343 STATE STREET      ROCHESTER NY 14650-0904
# 1               NaN    2799 CALIFORNIA ST  SAN FRANCISCO CA 94115-2513
# 2               NaN         8 MENDOSA AVE  SAN FRANCISCO CA 94116-1942
# 3               NaN  4444 GEARY BLVD. 100      SAN FRANCISCO CA 94118-
# 4               NaN  4444 GEARY BLVD. 100      SAN FRANCISCO CA 94118-
#
#   Class Code PBC Code                                  Business_Location  \
# 0         08     5995  343 STATE ST\nROCHESTER, NY 14650\n(43.161198,...
# 1         07     7520  3101 LAGUNA ST\nSan Francisco, CA 94123\n(37.7...
# 2         03     6511  8 MENDOSA AVE\nSan Francisco, CA 94116\n(37.74...
# 3         07     0211  1842 JEFFERSON ST\nSan Francisco, CA 94123\n(3...
# 4         07     0211  3301 BRODERICK ST\nSan Francisco, CA 94123\n(3...
#
#                             major_class
# 0  clothing, furniture, auto, insurance
# 1        mining, entertainment, medical
# 2                                 hotel
# 3        mining, entertainment, medical
# 4        mining, entertainment, medical

# %%
# %run ../code/makedbs.py
df = make_business()
print df.info()
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-178-a8694c969d02> in <module>()
#       1 get_ipython().magic(u'run ../code/makedbs.py')
# ----> 2 df = make_business()
#       3 print df.info()
#       4 df.head()
#
# /Users/crupley/gal/hoodie/code/makedbs.py in make_business()
#     167
#     168         # insert raw data
# --> 169         db_insert(df.ilot[:5,:], q_string)
#     170
#     171
#
# /Users/crupley/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2244                 return self[name]
#    2245             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2246                                  (type(self).__name__, name))
#    2247
#    2248     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ilot'

# %%
def getlatlon(v):
    if type(v) == float: return 0, 0
    s = v.split('\n')[-1]
    if len(s) == 0: return 0, 0
    return eval(s)

# %%
s = np.array(s)
s[s == 0].shape
# Out:
# (5026,)

# %%
for i in df.columns: print i
# Out:
# Ownership_Name
# DBA Name
# Street_Address
# City
# State
# Zip_Code
# major_class
# minor_class
# lat
# lon

# %%
# %run ../code/makedbs.py

# %%
df = load_business()

# %%
df = clean_business(df)
df.head()
# Out:
# <string>:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <string>:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <string>:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <string>:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Ownership_Name                   DBA Name     Street_Address  \
# 0   EASTMAN KODAK CO           EASTMAN KODAK CO       343 STATE ST
# 1    FERRANDO LOUISE           3101 LAGUNA APTS     3101 LAGUNA ST
# 2   IDEAL NOVAK CORP           IDEAL NOVAK CORP      8 MENDOSA AVE
# 3  TOURNAHU GEORGE L              TOURNAHU ARMS  1842 JEFFERSON ST
# 4  TOURNAHU GEORGE L  3301 BRODERICK APARTMENTS  3301 BRODERICK ST
#
#             City State  Zip_Code                           major_class  \
# 0      ROCHESTER    NY     14650  clothing, furniture, auto, insurance
# 1  San Francisco    CA     94123        mining, entertainment, medical
# 2  San Francisco    CA     94116                                 hotel
# 3  San Francisco    CA     94123        mining, entertainment, medical
# 4  San Francisco    CA     94123        mining, entertainment, medical
#
#    minor_class        lat         lon
# 0            0  43.161198  -77.619282
# 1            0  37.799779 -122.430988
# 2            0  37.748921 -122.465050
# 3            0  37.804734 -122.442997
# 4            0  37.800835 -122.444748

# %% [markdown]
# ## reorganize business categories

# %%
bus = get_db('business_raw')
print bus.shape
bus.head()
# Out:
# (156111, 17)
#       location_id  business_account_number     ownership_name  \
# 0  0000024-02-999                       24   EASTMAN KODAK CO
# 1  0000028-02-001                       28    FERRANDO LOUISE
# 2  0000052-01-001                       52   IDEAL NOVAK CORP
# 3  0000071-01-001                       71  TOURNAHU GEORGE L
# 4  0000071-02-001                       71  TOURNAHU GEORGE L
#
#                     dba_name     street_address           city state  \
# 0           EASTMAN KODAK CO       343 STATE ST      ROCHESTER    NY
# 1           3101 LAGUNA APTS     3101 LAGUNA ST  San Francisco    CA
# 2           IDEAL NOVAK CORP      8 MENDOSA AVE  San Francisco    CA
# 3              TOURNAHU ARMS  1842 JEFFERSON ST  San Francisco    CA
# 4  3301 BRODERICK APARTMENTS  3301 BRODERICK ST  San Francisco    CA
#
#    zip_code business_start_date business_end_date location_start_date  \
# 0     14650          01/01/2003               NaN          01/01/2003
# 1     94123          09/30/1993               NaN          09/30/1993
# 2     94116          10/01/1968               NaN          10/01/1968
# 3     94123          10/01/1968               NaN          10/01/1968
# 4     94123          10/01/1968               NaN          05/01/1988
#
#   location_end_date          mail_address          mail_city_state_zip  \
# 0               NaN      343 STATE STREET      ROCHESTER NY 14650-0904
# 1               NaN    2799 CALIFORNIA ST  SAN FRANCISCO CA 94115-2513
# 2               NaN         8 MENDOSA AVE  SAN FRANCISCO CA 94116-1942
# 3               NaN  4444 GEARY BLVD. 100      SAN FRANCISCO CA 94118-
# 4               NaN  4444 GEARY BLVD. 100      SAN FRANCISCO CA 94118-
#
#   class_code pbc_code                                  business_location
# 0         08     5995  343 STATE ST\nROCHESTER, NY 14650\n(43.161198,...
# 1         07     7520  3101 LAGUNA ST\nSan Francisco, CA 94123\n(37.7...
# 2         03     6511  8 MENDOSA AVE\nSan Francisco, CA 94116\n(37.74...
# 3         07     0211  1842 JEFFERSON ST\nSan Francisco, CA 94123\n(3...
# 4         07     0211  3301 BRODERICK ST\nSan Francisco, CA 94123\n(3...

# %%
from code.makedbs import *

# %%
major_names = {'00': 'Fixed Place of Business',
               '01': 'Commission Merchant or Broker (non-durable goods)',
               '02': 'General Contractors & Operative Builders',
               '03': 'Hotels, Apartments',
               '04': 'Coin-Operated Laundries, Dry Cleaning',
               '05': 'Credit Agencies, Lending Institutions',
               '06': 'Personal Property/Equipment Rental & Leasing',
               '07': 'Other Business Services',
               '08': 'Retail Sales',
               '09': 'Public Warehousing/Transportation/Storage/Freight Forwarding',
               '10': 'Communication Services; Utilities (Gas/Electric/Steam/Railroad)',
               '11': 'Transporting Persons for Hire',
               '12': 'Trucking/Hauling',
               '13': 'Wholesale Sales',
               '15': 'Architectural and Engingeering Services',
               '16': 'Non-Profit Garage Corporations',
               'n.a.': 'n.a.',
               'NaN': 'n.a.'}

# %%
busclean = bus[bus.location_end_date == 'NaN']
print busclean.shape
busclean['major_class'] = busclean.class_code.replace(major_names)
print busclean.shape
# Out:
# (129443, 17)
# (129443, 18)
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
busclean = clean_business(bus)
#busclean = cut_df(busclean)
print busclean.shape
busclean.head()
# Out:
# code/makedbs.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['major_class'] = df['class_code'].replace(major_names)
# code/makedbs.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df['pbc_code'] = df['pbc_code'].replace(['n.a.', 'NaN'], '8888')
# code/makedbs.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df['pbc_code'] = df['pbc_code'].astype('int')
# code/makedbs.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df['lat'] = df.business_location.apply(lambda x: getlatlon(x)[0])
# (124417, 12)
# code/makedbs.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df['lon'] = df.business_location.apply(lambda x: getlatlon(x)[1])
#       ownership_name                   dba_name     street_address  \
# 0   EASTMAN KODAK CO           EASTMAN KODAK CO       343 STATE ST
# 1    FERRANDO LOUISE           3101 LAGUNA APTS     3101 LAGUNA ST
# 2   IDEAL NOVAK CORP           IDEAL NOVAK CORP      8 MENDOSA AVE
# 3  TOURNAHU GEORGE L              TOURNAHU ARMS  1842 JEFFERSON ST
# 4  TOURNAHU GEORGE L  3301 BRODERICK APARTMENTS  3301 BRODERICK ST
#
#             city state  zip_code class_code  pbc_code  \
# 0      ROCHESTER    NY     14650         08      5995
# 1  San Francisco    CA     94123         07      7520
# 2  San Francisco    CA     94116         03      6511
# 3  San Francisco    CA     94123         07       211
# 4  San Francisco    CA     94123         07       211
#
#                major_class        lat         lon category
# 0             Retail Sales  43.161198  -77.619282        0
# 1  Other Business Services  37.799779 -122.430988        0
# 2       Hotels, Apartments  37.748921 -122.465050        0
# 3  Other Business Services  37.804734 -122.442997        0
# 4  Other Business Services  37.800835 -122.444748        0

# %%
busclean.groupby('class_code').count()
# Out:
#             ownership_name  dba_name  street_address    city   state  \
# class_code
# 00                      57        57              57      57      57
# 01                    6038      6038            6038    6038    6038
# 02                    5411      5411            5411    5411    5411
# 03                   19288     19288           19288   19288   19288
# 04                     808       808             808     808     808
# 05                     118       118             118     118     118
# 06                     479       479             479     479     479
# 07                   65222     65222           65222   65222   65222
# 08                   20708     20708           20708   20708   20708
# 09                     248       248             248     248     248
# 10                     282       282             282     282     282
# 11                    2537      2537            2537    2537    2537
# 12                     174       174             174     174     174
# 13                    3663      3663            3663    3663    3663
# 15                    1713      1713            1713    1713    1713
# 16                      12        12              12      12      12
# NaN                   4032      4032            4032    4032    4032
# n.a.                693792    693792          693792  693792  693792
#
#             zip_code  pbc_code  major_class     lat     lon  Description  \
# class_code
# 00                57        57           57      57      57           57
# 01              6038      6038         6038    6038    6038         6038
# 02              5411      5411         5411    5411    5411         5411
# 03             19288     19288        19288   19288   19288        19286
# 04               808       808          808     808     808          808
# 05               118       118          118     118     118          118
# 06               479       479          479     479     479          479
# 07             65222     65222        65222   65222   65222        65160
# 08             20708     20708        20708   20708   20708        20676
# 09               248       248          248     248     248          248
# 10               282       282          282     282     282          279
# 11              2537      2537         2537    2537    2537         2537
# 12               174       174          174     174     174          174
# 13              3663      3663         3663    3663    3663         3545
# 15              1713      1713         1713    1713    1713         1713
# 16                12        12           12      12      12           12
# NaN             4032      4032         4032    4032    4032         4032
# n.a.          693288    693792       693792  693792  693792       693792
#
#             category  lon_cut  lat_cut
# class_code
# 00                57       57       57
# 01              6038     6038     6038
# 02              5411     5411     5411
# 03             19288    19288    19288
# 04               808      808      808
# 05               118      118      118
# 06               479      479      479
# 07             65222    65222    65222
# 08             20708    20708    20708
# 09               248      248      248
# 10               282      282      282
# 11              2537     2537     2537
# 12               174      174      174
# 13              3663     3663     3663
# 15              1713     1713     1713
# 16                12       12       12
# NaN             4032     4032     4032
# n.a.          693792   693792   693792

# %%
codes = pd.read_csv('data/business/Principal_Business_Code__PBC__List.csv')
print codes.shape
codes.head()
# Out:
# (672, 4)
#   Ownership_Type  Business_Major_Class  Business_Minor_Class  \
# 0              S                     0                     0
# 1              P                     0                     0
# 2              C                     0                     0
# 3              S                     1                  2634
# 4              S                     1                  2675
#
#                        Description
# 0     FIXED PLACE OF BUSINESS BP99
# 1     FIXED PLACE OF BUSINESS BP99
# 2     FIXED PLACE OF BUSINESS BP99
# 3      AGENT/BROKER - DURABLE BP50
# 4   AGENT/BROKER - NONDURABLE BP51

# %%
codes.drop(['Ownership_Type', 'Business_Major_Class'], axis=1, inplace=True)
codes.set_index('Business_Minor_Class', inplace=True)
#codes = pd.Series(codes)
codes.Description.head()
# Out:
# Business_Minor_Class
# 0          FIXED PLACE OF BUSINESS BP99
# 0          FIXED PLACE OF BUSINESS BP99
# 0          FIXED PLACE OF BUSINESS BP99
# 2634        AGENT/BROKER - DURABLE BP50
# 2675     AGENT/BROKER - NONDURABLE BP51
# Name: Description, dtype: object

# %%
type(codes)
# Out:
# pandas.core.frame.DataFrame

# %%
busclean.pbc_code.replace(codes.Description).shape
# Out:
# (124417,)

# %%
busclean.groupby('major_class').count().sort_values('ownership_name', ascending=False)
# Out:
#                                                     ownership_name  dba_name  \
# major_class
# n.a.                                                        819468    819468
# Other Business Services                                      71017     71017
# Retail Sales                                                 22340     22340
# Hotels, Apartments                                           19388     19388
# General Contractors & Operative Builders                     14464     14464
# Commission Merchant or Broker (non-durable goods)             6480      6480
# Transporting Persons for Hire                                 4548      4548
# NaN                                                           4428      4428
# Wholesale Sales                                               4356      4356
# Architectural and Engingeering Services                       2013      2013
# Coin-Operated Laundries, Dry Cleaning                          827       827
# Personal Property/Equipment Rental & Leasing                   573       573
# Communication Services; Utilities (Gas/Electric...             540       540
# Public Warehousing/Transportation/Storage/Freig...             284       284
# Trucking/Hauling                                               236       236
# Credit Agencies, Lending Institutions                          124       124
# Fixed Place of Business                                         57        57
# Non-Profit Garage Corporations                                  12        12
#
#                                                     street_address    city  \
# major_class
# n.a.                                                        819468  819468
# Other Business Services                                      71017   71017
# Retail Sales                                                 22340   22340
# Hotels, Apartments                                           19388   19388
# General Contractors & Operative Builders                     14464   14464
# Commission Merchant or Broker (non-durable goods)             6480    6480
# Transporting Persons for Hire                                 4548    4548
# NaN                                                           4428    4428
# Wholesale Sales                                               4356    4356
# Architectural and Engingeering Services                       2013    2013
# Coin-Operated Laundries, Dry Cleaning                          827     827
# Personal Property/Equipment Rental & Leasing                   573     573
# Communication Services; Utilities (Gas/Electric...             540     540
# Public Warehousing/Transportation/Storage/Freig...             284     284
# Trucking/Hauling                                               236     236
# Credit Agencies, Lending Institutions                          124     124
# Fixed Place of Business                                         57      57
# Non-Profit Garage Corporations                                  12      12
#
#                                                      state  zip_code  \
# major_class
# n.a.                                                819468    818712
# Other Business Services                              71017     71011
# Retail Sales                                         22340     22340
# Hotels, Apartments                                   19388     19388
# General Contractors & Operative Builders             14464     14462
# Commission Merchant or Broker (non-durable goods)     6480      6480
# Transporting Persons for Hire                         4548      4547
# NaN                                                   4428      4428
# Wholesale Sales                                       4356      4356
# Architectural and Engingeering Services               2013      2013
# Coin-Operated Laundries, Dry Cleaning                  827       827
# Personal Property/Equipment Rental & Leasing           573       573
# Communication Services; Utilities (Gas/Electric...     540       540
# Public Warehousing/Transportation/Storage/Freig...     284       284
# Trucking/Hauling                                       236       236
# Credit Agencies, Lending Institutions                  124       124
# Fixed Place of Business                                 57        57
# Non-Profit Garage Corporations                          12        12
#
#                                                     class_code  pbc_code  \
# major_class
# n.a.                                                    819468    819468
# Other Business Services                                  71017     71017
# Retail Sales                                             22340     22340
# Hotels, Apartments                                       19388     19388
# General Contractors & Operative Builders                 14464     14464
# Commission Merchant or Broker (non-durable goods)         6480      6480
# Transporting Persons for Hire                             4548      4548
# NaN                                                       4428      4428
# Wholesale Sales                                           4356      4356
# Architectural and Engingeering Services                   2013      2013
# Coin-Operated Laundries, Dry Cleaning                      827       827
# Personal Property/Equipment Rental & Leasing               573       573
# Communication Services; Utilities (Gas/Electric...         540       540
# Public Warehousing/Transportation/Storage/Freig...         284       284
# Trucking/Hauling                                           236       236
# Credit Agencies, Lending Institutions                      124       124
# Fixed Place of Business                                     57        57
# Non-Profit Garage Corporations                              12        12
#
#                                                     category     lat     lon  \
# major_class
# n.a.                                                  819468  819468  819468
# Other Business Services                                71017   71017   71017
# Retail Sales                                           22340   22340   22340
# Hotels, Apartments                                     19388   19388   19388
# General Contractors & Operative Builders               14464   14464   14464
# Commission Merchant or Broker (non-durable goods)       6480    6480    6480
# Transporting Persons for Hire                           4548    4548    4548
# NaN                                                     4428    4428    4428
# Wholesale Sales                                         4356    4356    4356
# Architectural and Engingeering Services                 2013    2013    2013
# Coin-Operated Laundries, Dry Cleaning                    827     827     827
# Personal Property/Equipment Rental & Leasing             573     573     573
# Communication Services; Utilities (Gas/Electric...       540     540     540
# Public Warehousing/Transportation/Storage/Freig...       284     284     284
# Trucking/Hauling                                         236     236     236
# Credit Agencies, Lending Institutions                    124     124     124
# Fixed Place of Business                                   57      57      57
# Non-Profit Garage Corporations                            12      12      12
#
#                                                     Description
# major_class
# n.a.                                                     819468
# Other Business Services                                   70952
# Retail Sales                                              22308
# Hotels, Apartments                                        19386
# General Contractors & Operative Builders                  14464
# Commission Merchant or Broker (non-durable goods)          6480
# Transporting Persons for Hire                              4548
# NaN                                                        4428
# Wholesale Sales                                            4209
# Architectural and Engingeering Services                    2013
# Coin-Operated Laundries, Dry Cleaning                       827
# Personal Property/Equipment Rental & Leasing                573
# Communication Services; Utilities (Gas/Electric...          532
# Public Warehousing/Transportation/Storage/Freig...          284
# Trucking/Hauling                                            236
# Credit Agencies, Lending Institutions                       124
# Fixed Place of Business                                      57
# Non-Profit Garage Corporations                               12

# %%
busclean['category'] = '0'
print (busclean.category == '0').sum()
busclean.category[busclean.class_code == '00'] = 'other'
busclean.category[busclean.class_code == '01'] = 'other'
busclean.category[busclean.class_code == '02'] = 'other'
busclean.category[busclean.class_code == '03'] = 'hotel'
busclean.category[busclean.class_code == '04'] = 'laundry'
busclean.category[busclean.class_code == '05'] = 'other'
busclean.category[busclean.class_code == '06'] = 'other'
busclean.category[busclean.class_code == '09'] = 'other'
busclean.category[busclean.class_code == '10'] = 'other'
busclean.category[busclean.class_code == '11'] = 'other'
busclean.category[busclean.class_code == '12'] = 'other'
busclean.category[busclean.class_code == '13'] = 'other'
busclean.category[busclean.class_code == '15'] = 'other'
busclean.category[busclean.class_code == '16'] = 'other'

print busclean.groupby('category').count()['ownership_name']
# Out:
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/crupley/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 971155
# category
# 0          917253
# hotel       19388
# laundry       827
# other       33687
# Name: ownership_name, dtype: int64

# %%
busclean.class_code in ['08', '07']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-adc54c55ad5f> in <module>()
# ----> 1 busclean.class_code in ['08', '07']
#
# /Users/crupley/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     728         raise ValueError("The truth value of a {0} is ambiguous. "
#     729                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 730                          .format(self.__class__.__name__))
#     731
#     732     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# # sfpd

# %%
df = pd.read_csv('../data/sfpd/SFPD_Incidents_-_from_1_January_2003.csv')
df.head()
# Out:
#    IncidntNum        Category                               Descript  \
# 0   150912717  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 1   150912745        BURGLARY    BURGLARY, HOT PROWL, FORCIBLE ENTRY
# 2   150912698  OTHER OFFENSES                      TRAFFIC VIOLATION
# 3   150912795         ASSAULT                   THREATS AGAINST LIFE
# 4   150912701         ROBBERY                  ROBBERY, BODILY FORCE
#
#   DayOfWeek        Date   Time  PdDistrict      Resolution  \
# 0    Sunday  10/18/2015  23:54     TARAVAL  ARREST, BOOKED
# 1    Sunday  10/18/2015  23:37     CENTRAL  ARREST, BOOKED
# 2    Sunday  10/18/2015  23:34   INGLESIDE  ARREST, BOOKED
# 3    Sunday  10/18/2015  23:30  TENDERLOIN  ARREST, BOOKED
# 4    Sunday  10/18/2015  23:30    SOUTHERN            NONE
#
#                        Address           X          Y  \
# 0        19TH AV / HOLLOWAY AV -122.475222  37.721057
# 1          700 Block of BAY ST -122.419359  37.804838
# 2        PERSIA AV / DUBLIN ST -122.426390  37.718561
# 3  200 Block of LEAVENWORTH ST -122.414218  37.783259
# 4      1000 Block of MARKET ST -122.411340  37.781271
#
#                                 Location            PdId
# 0  (37.7210571460375, -122.475222189932)  15091271765016
# 1  (37.8048384367685, -122.419359266314)  15091274505081
# 2  (37.7185612508135, -122.426390080828)  15091269865015
# 3  (37.7832593295025, -122.414217804322)  15091279519057
# 4  (37.7812707434494, -122.411339562557)  15091270103074

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1830772 entries, 0 to 1830771
# Data columns (total 13 columns):
# IncidntNum    int64
# Category      object
# Descript      object
# DayOfWeek     object
# Date          object
# Time          object
# PdDistrict    object
# Resolution    object
# Address       object
# X             float64
# Y             float64
# Location      object
# PdId          int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 195.5+ MB

# %%
def listcols(df):
    for i in df.columns: print i

# %%
listcols(df)
# Out:
# IncidntNum
# Category
# Descript
# DayOfWeek
# Date
# Time
# PdDistrict
# Resolution
# Address
# X
# Y
# Location
# PdId

# %%
# %run ../code/makedbs.py

# %%
make_sfpd()

# %%
list(df.Category.unique())
# Out:
# ['OTHER OFFENSES',
#  'BURGLARY',
#  'ASSAULT',
#  'ROBBERY',
#  'WARRANTS',
#  'VANDALISM',
#  'NON-CRIMINAL',
#  'LARCENY/THEFT',
#  'STOLEN PROPERTY',
#  'FORGERY/COUNTERFEITING',
#  'VEHICLE THEFT',
#  'SUSPICIOUS OCC',
#  'DRUG/NARCOTIC',
#  'TRESPASS',
#  'FRAUD',
#  'WEAPON LAWS',
#  'MISSING PERSON',
#  'SECONDARY CODES',
#  'SEX OFFENSES, FORCIBLE',
#  'PORNOGRAPHY/OBSCENE MAT',
#  'ARSON',
#  'DISORDERLY CONDUCT',
#  'LOITERING',
#  'DRIVING UNDER THE INFLUENCE',
#  'LIQUOR LAWS',
#  'DRUNKENNESS',
#  'GAMBLING',
#  'KIDNAPPING',
#  'PROSTITUTION',
#  'EXTORTION',
#  'BRIBERY',
#  'SUICIDE',
#  'RUNAWAY',
#  'FAMILY OFFENSES',
#  'BAD CHECKS',
#  'EMBEZZLEMENT',
#  'SEX OFFENSES, NON FORCIBLE',
#  'TREA',
#  'RECOVERED VEHICLE']

# %%
df.groupby('Category').count().sort_values(by='Descript', ascending=False)
# Out:
#                              Descript    Date    Time  PdDistrict  Address  \
# Category
# LARCENY/THEFT                  370893  370893  370893      370893   370893
# OTHER OFFENSES                 261402  261402  261402      261402   261402
# NON-CRIMINAL                   193889  193889  193889      193889   193889
# ASSAULT                        160375  160375  160375      160375   160375
# VEHICLE THEFT                  111328  111328  111328      111328   111328
# DRUG/NARCOTIC                  109631  109631  109631      109631   109631
# VANDALISM                       93494   93494   93494       93494    93494
# WARRANTS                        87283   87283   87283       87283    87283
# BURGLARY                        76559   76559   76559       76559    76559
# SUSPICIOUS OCC                  65614   65614   65614       65614    65614
# MISSING PERSON                  53935   53935   53935       53935    53935
# ROBBERY                         47419   47419   47419       47419    47419
# FRAUD                           34903   34903   34903       34903    34903
# FORGERY/COUNTERFEITING          21516   21516   21516       21516    21516
# SECONDARY CODES                 20924   20924   20924       20924    20924
# WEAPON LAWS                     17951   17951   17951       17951    17951
# PROSTITUTION                    15362   15362   15362       15362    15362
# TRESPASS                        15190   15190   15190       15190    15190
# STOLEN PROPERTY                  9740    9740    9740        9740     9740
# SEX OFFENSES, FORCIBLE           9175    9175    9175        9175     9175
# DRUNKENNESS                      8833    8833    8833        8833     8833
# DISORDERLY CONDUCT               8729    8729    8729        8729     8729
# RECOVERED VEHICLE                6346    6346    6346        6346     6346
# DRIVING UNDER THE INFLUENCE      4834    4834    4834        4834     4834
# KIDNAPPING                       4756    4756    4756        4756     4756
# RUNAWAY                          3940    3940    3940        3940     3940
# LIQUOR LAWS                      3801    3801    3801        3801     3801
# ARSON                            3162    3162    3162        3162     3162
# EMBEZZLEMENT                     2520    2520    2520        2520     2520
# LOITERING                        2336    2336    2336        2336     2336
# SUICIDE                          1105    1105    1105        1105     1105
# FAMILY OFFENSES                  1062    1062    1062        1062     1062
# BAD CHECKS                        845     845     845         845      845
# BRIBERY                           647     647     647         647      647
# EXTORTION                         593     593     593         593      593
# SEX OFFENSES, NON FORCIBLE        326     326     326         326      326
# GAMBLING                          298     298     298         298      298
# PORNOGRAPHY/OBSCENE MAT            46      46      46          46       46
# TREA                               10      10      10          10       10
#
#                                   X       Y
# Category
# LARCENY/THEFT                370893  370893
# OTHER OFFENSES               261402  261402
# NON-CRIMINAL                 193889  193889
# ASSAULT                      160375  160375
# VEHICLE THEFT                111328  111328
# DRUG/NARCOTIC                109631  109631
# VANDALISM                     93494   93494
# WARRANTS                      87283   87283
# BURGLARY                      76559   76559
# SUSPICIOUS OCC                65614   65614
# MISSING PERSON                53935   53935
# ROBBERY                       47419   47419
# FRAUD                         34903   34903
# FORGERY/COUNTERFEITING        21516   21516
# SECONDARY CODES               20924   20924
# WEAPON LAWS                   17951   17951
# PROSTITUTION                  15362   15362
# TRESPASS                      15190   15190
# STOLEN PROPERTY                9740    9740
# SEX OFFENSES, FORCIBLE         9175    9175
# DRUNKENNESS                    8833    8833
# DISORDERLY CONDUCT             8729    8729
# RECOVERED VEHICLE              6346    6346
# DRIVING UNDER THE INFLUENCE    4834    4834
# KIDNAPPING                     4756    4756
# RUNAWAY                        3940    3940
# LIQUOR LAWS                    3801    3801
# ARSON                          3162    3162
# EMBEZZLEMENT                   2520    2520
# LOITERING                      2336    2336
# SUICIDE                        1105    1105
# FAMILY OFFENSES                1062    1062
# BAD CHECKS                      845     845
# BRIBERY                         647     647
# EXTORTION                       593     593
# SEX OFFENSES, NON FORCIBLE      326     326
# GAMBLING                        298     298
# PORNOGRAPHY/OBSCENE MAT          46      46
# TREA                             10      10

# %%
# %run ../code/makedbs.py
df = load_sfpd()
df = clean_sfpd(df)
print df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1830772 entries, 0 to 1830771
# Data columns (total 7 columns):
# Category      object
# Descript      object
# PdDistrict    object
# Address       object
# lon           float64
# lat           float64
# datetime      object
# dtypes: float64(2), object(5)
# memory usage: 111.7+ MB
# None
#          Category                               Descript  PdDistrict  \
# 0  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED     TARAVAL
# 1        BURGLARY    BURGLARY, HOT PROWL, FORCIBLE ENTRY     CENTRAL
# 2  OTHER OFFENSES                      TRAFFIC VIOLATION   INGLESIDE
# 3         ASSAULT                   THREATS AGAINST LIFE  TENDERLOIN
# 4         ROBBERY                  ROBBERY, BODILY FORCE    SOUTHERN
#
#                        Address         lon        lat          datetime
# 0        19TH AV / HOLLOWAY AV -122.475222  37.721057  10/18/2015 23:54
# 1          700 Block of BAY ST -122.419359  37.804838  10/18/2015 23:37
# 2        PERSIA AV / DUBLIN ST -122.426390  37.718561  10/18/2015 23:34
# 3  200 Block of LEAVENWORTH ST -122.414218  37.783259  10/18/2015 23:30
# 4      1000 Block of MARKET ST -122.411340  37.781271  10/18/2015 23:30

# %%
listcols(df)
# Out:
# Category
# Descript
# PdDistrict
# Address
# lon
# lat
# datetime

# %%
# %run ../code/makedbs.py
make_sfpd()

# %% [markdown]
# # US Census
# ## Age/gender

# %%
df = pd.read_csv('../data/uscensus/p12/DEC_10_SF1_P12.csv', skiprows=1)
print df.shape
df.head(1)
# Out:
# (7386, 52)
#                          Id             Id2  \
# 0  1000000US060750101001000  60750101001000
#
#                                            Geography  Total:  Male:  \
# 0  Block 1000, Block Group 1, Census Tract 101, S...       0      0
#
#    Male: - Under 5 years  Male: - 5 to 9 years  Male: - 10 to 14 years  \
# 0                      0                     0                       0
#
#    Male: - 15 to 17 years  Male: - 18 and 19 years  \
# 0                       0                        0
#
#               ...               Female: - 50 to 54 years  \
# 0             ...                                      0
#
#    Female: - 55 to 59 years  Female: - 60 and 61 years  \
# 0                         0                          0
#
#    Female: - 62 to 64 years  Female: - 65 and 66 years  \
# 0                         0                          0
#
#    Female: - 67 to 69 years  Female: - 70 to 74 years  \
# 0                         0                         0
#
#    Female: - 75 to 79 years  Female: - 80 to 84 years  \
# 0                         0                         0
#
#    Female: - 85 years and over
# 0                            0
#
# [1 rows x 52 columns]

# %%
df.Geography[0]
# Out:
# 'Block 1000, Block Group 1, Census Tract 101, San Francisco County, California'

# %%
def splitgeo(geo):
    s = geo.split(',')
    block = s[0].split(' ')[-1]
    blockgroup = s[1].split(' ')[-1]
    tract = s[2].split(' ')[-1]
    return block, blockgroup, tract
    
splitgeo(df.Geography[0])
# Out:
# ('1000', '1', '101')

# %%
df.Geography[:2].apply(splitgeo)
# Out:
# 0    (1000, 1, 101)
# 1    (1001, 1, 101)
# Name: Geography, dtype: object

# %%
df['geovalues'] = df.Geography.apply(splitgeo)

# %%
cols = ['Block', 'Block_Group', 'Tract']
for n, col in enumerate(cols):
    df[col] = df.geovalues.apply(lambda x: x[n])
df.head(1)
# Out:
#                          Id             Id2  \
# 0  1000000US060750101001000  60750101001000
#
#                                            Geography  Total:  Male:  \
# 0  Block 1000, Block Group 1, Census Tract 101, S...       0      0
#
#    Male: - Under 5 years  Male: - 5 to 9 years  Male: - 10 to 14 years  \
# 0                      0                     0                       0
#
#    Male: - 15 to 17 years  Male: - 18 and 19 years  ...    \
# 0                       0                        0  ...
#
#    Female: - 65 and 66 years  Female: - 67 to 69 years  \
# 0                          0                         0
#
#    Female: - 70 to 74 years  Female: - 75 to 79 years  \
# 0                         0                         0
#
#    Female: - 80 to 84 years  Female: - 85 years and over       geovalues  \
# 0                         0                            0  (1000, 1, 101)
#
#    Block  Block_Group  Tract
# 0   1000            1    101
#
# [1 rows x 56 columns]

# %%
# %run code/makedbs.py
df = pd.read_csv('data/uscensus/p12/DEC_10_SF1_P12.csv', skiprows=1)
df = clean_usc_age_gender(df)
df.head(1)
# Out:
#   Block Block_Group Tract             Id2  Total  M  M_U5  M_5_9  M_10_14  \
# 0   101           1  1000  60750101001000      0  0     0      0        0
#
#    M_15_17    ...      F_50_54  F_55_59  F_60_61  F_62_64  F_65_66  F_67_69  \
# 0        0    ...            0        0        0        0        0        0
#
#    F_70_74  F_75_79  F_80_84  F_85_over
# 0        0        0        0          0
#
# [1 rows x 53 columns]

# %%
for i in df.columns: print i
# Out:
# Block
# Block_Group
# Tract
# Total
# M
# M_U5
# M_5_9
# M_10_14
# M_15_17
# M_18_19
# M_20
# M_21
# M_22_24
# M_25_29
# M_30_34
# M_35_39
# M_40_44
# M_45_49
# M_50_54
# M_55_59
# M_60_61
# M_62_64
# M_65_66
# M_67_69
# M_70_74
# M_75_79
# M_80_84
# M_85_over
# F
# F_U5
# F_5_9
# F_10_14
# F_15_17
# F_18_19
# F_20
# F_21
# F_22_24
# F_25_29
# F_30_34
# F_35_39
# F_40_44
# F_45_49
# F_50_54
# F_55_59
# F_60_61
# F_62_64
# F_65_66
# F_67_69
# F_70_74
# F_75_79
# F_80_84
# F_85_over

# %%
df.Tract.astype('int').unique()
# Out:
# array([1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010,
#        1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021,
#        1022, 1023, 1024, 1025, 1026, 1027, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 3000, 3001, 3002, 3003, 3004, 3005, 3006,
#        3007, 3008, 3009, 3010, 3011, 3012, 3013, 3014, 4000, 4001, 4002,
#        4003, 4004, 2020, 2021, 1028, 1029, 1030, 1031, 2022, 2023, 2024,
#        2025, 2026, 2027, 2028, 2029, 4005, 4006, 4007, 3015, 3016, 3017,
#        3018, 3019, 4008, 4009, 4010, 5000, 5001, 5002, 5003, 5004, 5005,
#        5006, 5007, 4011, 5008, 5009, 5010, 1032, 1033, 1034, 1035, 1036,
#        1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047,
#        1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058,
#        1059, 1060, 1061, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037,
#        2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 1062,
#        1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073,
#        1074, 1075, 1076, 1077, 1078, 1079, 1080, 4012, 4013, 4014, 3020,
#        3021, 3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3030, 3031,
#        3032, 3033, 3034, 3035, 3036, 3037, 3038, 3039, 3040, 3041, 3042,
#        3043, 3044, 3045, 3046, 3047, 6000, 6001, 6002, 6003, 6004, 6005,
#        6006, 6007, 6008, 6009, 6010, 6011, 6012, 6013, 6014, 6015, 6016,
#        6017, 6018, 6019, 6020, 6021, 6022, 6023, 6024, 6025, 6026, 6027,
#        6028, 6029, 6030, 6031, 6032, 2048, 2049, 2050, 4015, 4016, 4017,
#        4018, 4019, 4020, 4021, 4022, 4023, 4024, 5011, 5012, 5013, 5014,
#        5015, 5016, 5017, 5018, 5019, 5020, 4025, 4026, 4027, 4028, 5021,
#        7000, 7001, 7002, 7003, 7004, 7005, 7006, 7007, 7008, 7009, 7010,
#        7011, 7012, 7013, 7014, 7015, 7016, 7017, 7018, 7019, 7020, 4029,
#        4030, 4031, 4032, 4033, 4034, 1081, 1082, 1083, 1084, 1085, 1086,
#        1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097,
#        1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108,
#        1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119,
#        1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130,
#        1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141,
#        1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152,
#        1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163,
#        1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174,
#        1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185,
#        1186, 1187,    1,    2,    3,    4,    5,    6])

# %%
# %run code/makedbs.py
make_usc_age_gender()

# %% [markdown]
# ## US Census household size

# %%
# %run code/makedbs.py
df = load_usc_household()
print df.shape
df.head(1)
# Out:
# (7386, 11)
#                          Id             Id2  \
# 0  1000000US060750101001000  60750101001000
#
#                                            Geography  Total:  \
# 0  Block 1000, Block Group 1, Census Tract 101, S...       0
#
#    1-person household  2-person household  3-person household  \
# 0                   0                   0                   0
#
#    4-person household  5-person household  6-person household  \
# 0                   0                   0                   0
#
#    7-or-more-person household
# 0                           0

# %%
# %run code/makedbs.py
df = load_usc_household()
df = clean_usc_household(df)
df.head(1)
# Out:
#   Block Block_Group Tract             Id2  Total  p1  p2  p3  p4  p5  p6  p7
# 0   101           1  1000  60750101001000      0   0   0   0   0   0   0   0

# %%
fnames = []
for name in cnames:
    pp = ''
    if re.match('[0-9]', name): pp = 'p'
    fnames.append(pp + name)

# %%
fnames
# Out:
# ['Block',
#  'Block_Group',
#  'Tract',
#  'Total',
#  'p1_person',
#  'p2_person',
#  'p3_person',
#  'p4_person',
#  'p5_person',
#  'p6_person',
#  'p7_person']

# %%
for i in df.columns: print i
# Out:
# Block
# Block_Group
# Tract
# Total
# p1
# p2
# p3
# p4
# p5
# p6
# p7

# %%
# %run code/makedbs.py
make_usc_household()

# %% [markdown]
# ## US Census population

# %%
# %run code/makedbs.py
df = load_usc_pop()
df.head(1)
# Out:
#                          Id             Id2  \
# 0  1000000US060750101001000  60750101001000
#
#                                            Geography  Total
# 0  Block 1000, Block Group 1, Census Tract 101, S...      0

# %%
# %run code/makedbs.py
df = load_usc_pop()
df = clean_usc_pop(df)
df.head(1)
# Out:
#   Block Block_Group Tract             Id2  Total
# 0   101           1  1000  60750101001000      0

# %%
for i in df.columns: print i
# Out:
# Block
# Block_Group
# Tract
# Id2
# Total

# %%
# %run code/makedbs.py
make_usc_pop()

# %% [markdown]
# # Walkscore

# %%
conn = psycopg2.connect(dbname='hoodie', user='postgres', host='/tmp')
c = conn.cursor()

c.execute('SELECT * FROM walkscore_raw')

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL

# %%
DATABASE = {
    'drivername': 'postgres',
    'host': 'localhost',
    'username': 'postgres',
    'database': 'hoodie'
}

# %%
URL(**DATABASE)
# Out:
# postgres://postgres@localhost/hoodie

# %%
engine = create_engine(URL(**DATABASE))

# %%
with engine.connect() as conn, conn.begin():
    df = pd.read_sql_table('walkscore_raw', conn)
df.head()
# Out:
#      description                                    help_link  \
# 0  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 1  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 2  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 3  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 4  Car-Dependent  https://www.redfin.com/how-walk-score-works
#
#                                   logo_url  \
# 0  https://cdn.walk.sc/images/api-logo.png
# 1  https://cdn.walk.sc/images/api-logo.png
# 2  https://cdn.walk.sc/images/api-logo.png
# 3  https://cdn.walk.sc/images/api-logo.png
# 4  https://cdn.walk.sc/images/api-logo.png
#
#                                  more_info_icon  \
# 0  https://cdn.walk.sc/images/api-more-info.gif
# 1  https://cdn.walk.sc/images/api-more-info.gif
# 2  https://cdn.walk.sc/images/api-more-info.gif
# 3  https://cdn.walk.sc/images/api-more-info.gif
# 4  https://cdn.walk.sc/images/api-more-info.gif
#
#                                 more_info_link  snapped_lat  snapped_lon  \
# 0  https://www.redfin.com/how-walk-score-works      37.7190    -122.5185
# 1  https://www.redfin.com/how-walk-score-works      37.7205    -122.5185
# 2  https://www.redfin.com/how-walk-score-works      37.7220    -122.5185
# 3  https://www.redfin.com/how-walk-score-works      37.7235    -122.5185
# 4  https://www.redfin.com/how-walk-score-works      37.7250    -122.5185
#
#    status                    updated walkscore  \
# 0       1 2013-08-10 17:19:49.723670         1
# 1       1 2015-06-16 02:11:34.261700         0
# 2       1 2013-08-10 17:20:27.329400         2
# 3       1 2014-09-05 10:53:05.520620         0
# 4       1 2015-06-16 02:11:33.920510         0
#
#                                              ws_link  searched_lat  \
# 0  https://www.walkscore.com/score/loc/lat=37.719...     37.719347
# 1  https://www.walkscore.com/score/loc/lat=37.720...     37.720717
# 2  https://www.walkscore.com/score/loc/lat=37.722...     37.722088
# 3  https://www.walkscore.com/score/loc/lat=37.723...     37.723458
# 4  https://www.walkscore.com/score/loc/lat=37.724...     37.724829
#
#    searched_lon
# 0   -122.518079
# 1   -122.518079
# 2   -122.518079
# 3   -122.518079
# 4   -122.518079

# %%
# %run code/makedbs.py
df = get_db('walkscore_raw')
print df.shape
df.head()
# Out:
# (5476, 13)
#      description                                    help_link  \
# 0  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 1  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 2  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 3  Car-Dependent  https://www.redfin.com/how-walk-score-works
# 4  Car-Dependent  https://www.redfin.com/how-walk-score-works
#
#                                   logo_url  \
# 0  https://cdn.walk.sc/images/api-logo.png
# 1  https://cdn.walk.sc/images/api-logo.png
# 2  https://cdn.walk.sc/images/api-logo.png
# 3  https://cdn.walk.sc/images/api-logo.png
# 4  https://cdn.walk.sc/images/api-logo.png
#
#                                  more_info_icon  \
# 0  https://cdn.walk.sc/images/api-more-info.gif
# 1  https://cdn.walk.sc/images/api-more-info.gif
# 2  https://cdn.walk.sc/images/api-more-info.gif
# 3  https://cdn.walk.sc/images/api-more-info.gif
# 4  https://cdn.walk.sc/images/api-more-info.gif
#
#                                 more_info_link  snapped_lat  snapped_lon  \
# 0  https://www.redfin.com/how-walk-score-works      37.7190    -122.5185
# 1  https://www.redfin.com/how-walk-score-works      37.7205    -122.5185
# 2  https://www.redfin.com/how-walk-score-works      37.7220    -122.5185
# 3  https://www.redfin.com/how-walk-score-works      37.7235    -122.5185
# 4  https://www.redfin.com/how-walk-score-works      37.7250    -122.5185
#
#    status                    updated walkscore  \
# 0       1 2013-08-10 17:19:49.723670         1
# 1       1 2015-06-16 02:11:34.261700         0
# 2       1 2013-08-10 17:20:27.329400         2
# 3       1 2014-09-05 10:53:05.520620         0
# 4       1 2015-06-16 02:11:33.920510         0
#
#                                              ws_link  searched_lat  \
# 0  https://www.walkscore.com/score/loc/lat=37.719...     37.719347
# 1  https://www.walkscore.com/score/loc/lat=37.720...     37.720717
# 2  https://www.walkscore.com/score/loc/lat=37.722...     37.722088
# 3  https://www.walkscore.com/score/loc/lat=37.723...     37.723458
# 4  https://www.walkscore.com/score/loc/lat=37.724...     37.724829
#
#    searched_lon
# 0   -122.518079
# 1   -122.518079
# 2   -122.518079
# 3   -122.518079
# 4   -122.518079

# %%
# %run code/makedbs.py
df = get_db('walkscore_raw')
df = clean_walkscore(df)
print df.shape
print df.info()
df.head()
# Out:
# (5032, 7)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5032 entries, 0 to 5475
# Data columns (total 7 columns):
# snapped_lat     5032 non-null float64
# snapped_lon     5032 non-null float64
# walkscore       5032 non-null int64
# description     5032 non-null object
# updated         5032 non-null datetime64[ns]
# searched_lat    5032 non-null float64
# searched_lon    5032 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 314.5+ KB
# None
#    snapped_lat  snapped_lon  walkscore    description  \
# 0      37.7190    -122.5185          1  Car-Dependent
# 1      37.7205    -122.5185          0  Car-Dependent
# 2      37.7220    -122.5185          2  Car-Dependent
# 3      37.7235    -122.5185          0  Car-Dependent
# 4      37.7250    -122.5185          0  Car-Dependent
#
#                      updated  searched_lat  searched_lon
# 0 2013-08-10 17:19:49.723670     37.719347   -122.518079
# 1 2015-06-16 02:11:34.261700     37.720717   -122.518079
# 2 2013-08-10 17:20:27.329400     37.722088   -122.518079
# 3 2014-09-05 10:53:05.520620     37.723458   -122.518079
# 4 2015-06-16 02:11:33.920510     37.724829   -122.518079

# %%
for i in df.columns: print i
# Out:
# snapped_lat
# snapped_lon
# walkscore
# description
# updated
# searched_lat
# searched_lon

# %%
# %run code/makedbs.py
make_walkscore()

# %% [markdown]
# # Shapefiles

# %%
df = load_usc_pop()
df = clean_usc_pop(df)
df.head()
# Out:
#   Block Block_Group Tract  Total
# 0   101           1  1000      0
# 1   101           1  1001     44
# 2   101           1  1002      0
# 3   101           1  1003      0
# 4   101           1  1004      1

# %%
print df.Id2.unique().min()
print df.Id2.unique().max()
# Out:
# 60750101001000
# 60759901000006

# %%
# %cd ..
# Out:
# /Users/crupley/gal/hoodie

# %%
# %run code/shapefiles.py
rdf = sf_to_df('data/uscensus/tl_2010_06075_tabblock10/tl_2010_06075_tabblock10.dbf')
print rdf.shape
print rdf.info()
rdf.head()
# Out:
# (7386, 11)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7386 entries, 0 to 7385
# Data columns (total 11 columns):
# state         7386 non-null object
# county        7386 non-null object
# tract         7386 non-null object
# block         7386 non-null object
# geoid         7386 non-null int64
# name          7386 non-null object
# mtfcc         7386 non-null object
# land_area     7386 non-null int64
# water_area    7386 non-null int64
# lat           7386 non-null float64
# lon           7386 non-null float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 692.4+ KB
# None
#   state county   tract block           geoid        name  mtfcc  land_area  \
# 0    06    075  021300  2002  60750213002002  Block 2002  G5040      16958
# 1    06    075  021300  2000  60750213002000  Block 2000  G5040      16823
# 2    06    075  020500  3004  60750205003004  Block 3004  G5040      17020
# 3    06    075  021200  1003  60750212001003  Block 1003  G5040      16415
# 4    06    075  021100  4001  60750211004001  Block 4001  G5040      17523
#
#    water_area        lat         lon
# 0           0  37.750067 -122.441075
# 1           0  37.750196 -122.438933
# 2           0  37.756794 -122.436270
# 3           0  37.753529 -122.437050
# 4           0  37.755758 -122.433400

# %%
for i in rdf.columns: print i
# Out:
# state
# county
# tract
# block
# geoid
# name
# mtfcc
# land_area
# water_area
# lat
# lon

# %%
# %run code/makedbs.py
df = load_usc_shapefile()

# %%
#make_usc_shapefile()

# %%
make_usc_age_gender()

# %%
make_usc_household()

# %%
make_usc_pop()

# %%
make_usc_shapefile()
